# %% [markdown]
# <a href="https://colab.research.google.com/github/oktaviacitra/deep-metric-learning/blob/main/CARS196.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow_datasets as tfds

image, label = tfds.as_numpy(tfds.load(
    'cars196',
    batch_size=-1,
    as_supervised=True,
))
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/8144 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/cars196/2.1.0.incompleteCU0RXX/cars196-train.tfrecord*...:   0%|          | 0/…
# Generating test examples...:   0%|          | 0/8041 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/cars196/2.1.0.incompleteCU0RXX/cars196-test.tfrecord*...:   0%|          | 0/8…
# Dataset cars196 downloaded and prepared to ~/tensorflow_datasets/cars196/2.1.0. Subsequent calls will reuse this data.
